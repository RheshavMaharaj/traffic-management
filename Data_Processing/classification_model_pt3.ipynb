# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras import layers

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
#reading the dataset

hourly_samples_path = 'https://drive.google.com/uc?export=download&id=1di7YkJN_eXvq3xkKj2dPp4Z0Rc9qhlkQ'
dataframe = pd.read_csv(hourly_samples_path)

#https://drive.google.com/file/d/1di7YkJN_eXvq3xkKj2dPp4Z0Rc9qhlkQ/view?usp=sharing
#https://drive.google.com/file/d/1di7YkJN_eXvq3xkKj2dPp4Z0Rc9qhlkQ/view?usp=sharing
#https://drive.google.com/file/d/1di7YkJN_eXvq3xkKj2dPp4Z0Rc9qhlkQ/view?usp=sharing

# %%
dataframe = dataframe.convert_dtypes()
print(dataframe.dtypes)
# Out:
# station_key               Int64
# full_name                string
# latitude                Float64
# longitude               Float64
# daily_total               Int64
# day_of_week               Int64
# public_holiday            Int64
# school_holiday            Int64
# time (hours)             string
# traffic_hourly_count      Int64
# threshold               Float64
# dtype: object

# %%
#traffic_max = df['time (hours)':['hour_00', 'hour_01', 'hour_02', 'hour_03', 'hour_04', 'hour_05', 'hour_06', 'hour_07', 'hour_08', 'hour_09', 'hour_10', 'hour_11', 'hour_12', 'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_17', 'hour_18', 'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23']].max(axis=1)
dataframe.head()
# Out:
#    station_key                              full_name   latitude   longitude  \
# 0        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 1        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 2        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 3        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 4        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
#
#    daily_total  day_of_week  public_holiday  school_holiday time (hours)  \
# 0        70880            5               0               0      hour_00
# 1        70880            5               0               0      hour_01
# 2        70880            5               0               0      hour_02
# 3        70880            5               0               0      hour_03
# 4        70880            5               0               0      hour_04
#
#    traffic_hourly_count  threshold
# ...

# %%
dataframe['congested'] = np.where(dataframe.traffic_hourly_count >= dataframe.threshold, 0, 1)
dataframe.head(10)
# Out:
#    station_key                              full_name   latitude   longitude  \
# 0        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 1        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 2        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 3        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 4        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 5        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 6        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 7        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 8        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 9        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
#
#    daily_total  day_of_week  public_holiday  school_holiday time (hours)  \
# ...

# %%
# Drop unused features.
dataframe['target'] = np.where(dataframe['congested']==4,0, 1)

dataframe = dataframe.drop(columns=['threshold', 'congested'])

# %%
dataframe.head()
# Out:
#    station_key                              full_name   latitude   longitude  \
# 0        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 1        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 2        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 3        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
# 4        57299  Western Motorway, South of Ponds Road -33.806267  150.922424
#
#    daily_total  day_of_week  public_holiday  school_holiday time (hours)  \
# 0        70880            5               0               0      hour_00
# 1        70880            5               0               0      hour_01
# 2        70880            5               0               0      hour_02
# 3        70880            5               0               0      hour_03
# 4        70880            5               0               0      hour_04
#
#    traffic_hourly_count  target
# ...

# %%
print(dataframe.ndim)
# Out:
# 2

# %%
train, val, test = np.split(dataframe.sample(frac=1), [int(0.8*len(dataframe)), int(0.9*len(dataframe))])

# %%
print(len(train), 'training examples')
print(len(val), 'validation examples')
print(len(test), 'test examples')
# Out:
# 288 training examples
# 36 validation examples
# 36 test examples

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=32):
  df = dataframe.copy()
  labels = df.pop('target')
  df = {key: value[:,tf.newaxis] for key, value in dataframe.items()}
  ds = tf.data.Dataset.from_tensor_slices((dict(df), labels))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  ds = ds.prefetch(batch_size)
  return ds

# %%
batch_size = 5
train_ds = df_to_dataset(train, batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_values(self, indexer)
#    1025         try:
# -> 1026             new_mgr = self._mgr.getitem_mgr(indexer)
#    1027             return self._constructor(new_mgr).__finalize__(self)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in getitem_mgr(self, indexer)
#    1635         blk = self._block
# -> 1636         array = blk._slice(indexer)
#    1637         if array.ndim > 1:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in _slice(self, slicer)
#    1556
# -> 1557         return self.values[slicer]
#    1558
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/masked.py in __getitem__(self, item)
#     145
# --> 146         return type(self)(self._data[item], self._mask[item])
#     147
#
# ...
